# %%
import array
from itertools import count

# %%
arr = array.array('i',[1,2,3,4,5])

# %%
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
import random

# %%
lis = []
for i in range(1000):
    lis.append(random.random())

# %%
lis[:5]
# Out:
# [0.43386228752361744,
#  0.15224646594272717,
#  0.9687006744981542,
#  0.09912374987834727,
#  0.45511963941744815]

# %%
random.choice(lis)
# Out:
# 0.1959001139266351

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/adhyayan/Desktop/Machine Learning/Basic Python

# %%
count = 0;
